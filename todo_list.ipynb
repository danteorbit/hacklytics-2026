# %% [markdown]
# **Tasks**
# - Get stock symbols for top 50 companies
# - Get financials (Quarterly revenue sheet) for top 50 companies
# - Make a Decision Tree on whether it will correct or not
# - Make a Website to display everything and possibly search for your own symbol

# %% [markdown]
# **Get stock symbols for top 50 companies**
# - Get top 50 symbols from S&P 500
# - Use an API to get the symbols and their values during date ranges
# - Get 3-5 years of data

# %% [markdown]
# **Get financials (Quarterly revenue Q1...Q4)**
# - RAG to quickly get the financials and make a summary from them with important values
# - Do this for every quarter and every year (Make a pipeline)
# - Make a Database to see them and plot their revenue and Profit/Loss data

# %% [markdown]
# **Make an AIML prediction model (Decision Trees or Random Forest)**
# - Make them predict whether it will price correct or not
# - Make a prediction on if the value will go up or down

# %% [markdown]
# **Make a website!**
# - Have multiple pages that ask what symbol you want to see or create a portfolio
# - Show a summary of the financials
# - Show whether the company is above or below value (from queuing the backend)
# - Show if they corrected or not after the quarter report
# - Show their 3-5 year profit/loss (from backend)
# -
